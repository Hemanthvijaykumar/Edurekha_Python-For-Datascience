# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Question 1:
# ### a) a. Load the dataset “prisoners.csv” using pandas and display the first and last five rows in the dataset.

# %%
data = pd.read_csv('prisoners.csv')
data.shape
# Out:
# (35, 6)

# %%
data.head()
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
#
#    No. of Inmates benefitted by Higher Education  \
# 0                                            672
# 1                                              0
# 2                                             14
# 3                                            125
# 4                                            192
#
#    No. of Inmates benefitted by Computer Course
# 0                                           170
# 1                                             0
# 2                                            30
# 3                                          1417
# 4                                           103

# %%
data.tail()
# Out:
#         STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 30  D & N Haveli  2013                                                  0
# 31   Daman & Diu  2013                                                  0
# 32         Delhi  2013                                               1458
# 33   Lakshadweep  2013                                                  0
# 34   Pondicherry  2013                                                  0
#
#     No. of Inmates benefitted by Adult Education  \
# 30                                             0
# 31                                             0
# 32                                          1187
# 33                                             0
# 34                                             0
#
#     No. of Inmates benefitted by Higher Education  \
# 30                                              0
# 31                                              0
# 32                                            908
# 33                                              0
# 34                                              0
#
#     No. of Inmates benefitted by Computer Course
# 30                                             0
# 31                                             0
# 32                                           174
# 33                                             0
# 34                                             0

# %% [markdown]
# ### b. Use describe method in pandas and find out the number of columns. Can you say something about those rows who have zero inmates?

# %%
data.describe()
# Out:
#          YEAR  No. of Inmates benefitted by Elementary Education  \
# count    35.0                                          35.000000
# mean   2013.0                                        1057.914286
# std       0.0                                        2078.196777
# min    2013.0                                           0.000000
# 25%    2013.0                                           0.000000
# 50%    2013.0                                         167.000000
# 75%    2013.0                                        1294.500000
# max    2013.0                                        9480.000000
#
#        No. of Inmates benefitted by Adult Education  \
# count                                     35.000000
# mean                                    1534.857143
# std                                     3022.110503
# min                                        0.000000
# 25%                                        6.500000
# 50%                                      237.000000
# 75%                                     1733.500000
# max                                    13758.000000
#
#        No. of Inmates benefitted by Higher Education  \
# count                                      35.000000
# mean                                      237.457143
# std                                       375.614191
# min                                         0.000000
# 25%                                         2.000000
# 50%                                        33.000000
# 75%                                       234.500000
# max                                      1353.000000
#
#        No. of Inmates benefitted by Computer Course
# count                                     35.000000
# mean                                     210.171429
# std                                      359.117340
# min                                        0.000000
# 25%                                        0.000000
# 50%                                       38.000000
# 75%                                      227.500000
# max                                     1417.000000

# %%
data.loc[data['No. of Inmates benefitted by Elementary Education'] == 0]
# Out:
#              STATE/UT  YEAR  \
# 1   Arunachal Pradesh  2013
# 15            Manipur  2013
# 17            Mizoram  2013
# 18           Nagaland  2013
# 22             Sikkim  2013
# 29         Chandigarh  2013
# 30       D & N Haveli  2013
# 31        Daman & Diu  2013
# 33        Lakshadweep  2013
# 34        Pondicherry  2013
#
#     No. of Inmates benefitted by Elementary Education  \
# 1                                                   0
# 15                                                  0
# 17                                                  0
# 18                                                  0
# 22                                                  0
# 29                                                  0
# 30                                                  0
# 31                                                  0
# 33                                                  0
# 34                                                  0
#
#     No. of Inmates benefitted by Adult Education  \
# 1                                              0
# 15                                             0
# 17                                            25
# 18                                             0
# 22                                             0
# 29                                           265
# 30                                             0
# 31                                             0
# 33                                             0
# 34                                             0
#
#     No. of Inmates benefitted by Higher Education  \
# 1                                               0
# 15                                              0
# 17                                             18
# 18                                              0
# 22                                              0
# 29                                             85
# 30                                              0
# 31                                              0
# 33                                              0
# 34                                              0
#
#     No. of Inmates benefitted by Computer Course
# 1                                              0
# 15                                             0
# 17                                             0
# 18                                             0
# 22                                             0
# 29                                             0
# 30                                             0
# 31                                             0
# 33                                             0
# 34                                             0

# %% [markdown]
# ### 2. Data Manipulation:
# ### a. Create a new column -’total_benefitted’ that is a sum of inmates benefitted through all modes.

# %%
data['total_benefitted'] = data['No. of Inmates benefitted by Elementary Education'] + data['No. of Inmates benefitted by Adult Education'] + data['No. of Inmates benefitted by Higher Education'] + data['No. of Inmates benefitted by Computer Course']

# %%
data.head()
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
#
#    No. of Inmates benefitted by Higher Education  \
# 0                                            672
# 1                                              0
# 2                                             14
# 3                                            125
# 4                                            192
#
#    No. of Inmates benefitted by Computer Course  total_benefitted
# 0                                           170             24080
# 1                                             0                 0
# 2                                            30              1470
# 3                                          1417              6248
# 4                                           103              3762

# %% [markdown]
# ### b. Create a new row - “totals” that is the sum of all inmates benefitted through each mode across all states.

# %%
data = data.append(data.sum(), ignore_index=True)
data.at[35, "STATE/UT"] = "totals"
data.tail()
# Out:
#                                              STATE/UT     YEAR  \
# 35                                             totals    70455
# 36  Andhra PradeshArunachal PradeshAssamBiharChhat...   140910
# 37  Andhra PradeshArunachal PradeshAssamBiharChhat...   281820
# 38  Andhra PradeshArunachal PradeshAssamBiharChhat...   563640
# 39  Andhra PradeshArunachal PradeshAssamBiharChhat...  1127280
#
#     No. of Inmates benefitted by Elementary Education  \
# 35                                              37027
# 36                                              74054
# 37                                             148108
# 38                                             296216
# 39                                             592432
#
#     No. of Inmates benefitted by Adult Education  \
# 35                                         53720
# 36                                        107440
# 37                                        214880
# 38                                        429760
# 39                                        859520
#
#     No. of Inmates benefitted by Higher Education  \
# 35                                           8311
# 36                                          16622
# 37                                          33244
# 38                                          66488
# 39                                         132976
#
#     No. of Inmates benefitted by Computer Course  total_benefitted
# 35                                          7356            106414
# 36                                         14712            212828
# 37                                         29424            425656
# 38                                         58848            851312
# 39                                        117696           1702624

# %% [markdown]
# ### 3. Plotting:
# ### a. Make a bar plot with each state name on the x -axis and their total benefitted inmates as their bar heights. Which state has the maximum number of beneficiaries?

# %%
plt.figure(figsize=(10,6))
plt.bar(x=data['STATE/UT'],height=data['total_benefitted'])
plt.title("STATE/UT vs Total_inmates_benefitted")
plt.xlabel("STATE/UT")
plt.ylabel("Total_inmates_benefitted")
plt.setp(plt.gca().get_xticklabels(), rotation=90,horizontalalignment='right') 
plt.show()

# %% [markdown]
# ### b. Make a pie chart that depicts the ratio among different modes of benefits.

# %%
labels = data["STATE/UT"]
values = data["total_benefitted"]

plt.figure(figsize=(8,8))
plt.pie(values, labels = labels, autopct='%1.1f%%', shadow=True)
plt.title("STATE/UT vs Total_inmates_benefitted")
plt.show()
